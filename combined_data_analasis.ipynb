# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
df1 = pd.read_csv("combined_data.csv")

# %%
print(df1)
# Out:
#           Scheme_Category        Date  No_of_Folios  SIP_Contribution_Cr  \
# 0          Large Cap Fund  2025-09-01      16625122          5576.818740
# 1    Large & Mid Cap Fund  2025-09-01      12853471          6769.399720
# 2            Mid Cap Fund  2025-09-01      23343247          8793.498189
# 3          Small Cap Fund  2025-09-01      26894961          8065.520901
# 4          Large Cap Fund  2025-08-01      16539476          5475.398084
# ..                    ...         ...           ...                  ...
# 307        Small Cap Fund  2019-05-01       4992445          2172.861584
# 308        Large Cap Fund  2019-04-01       8179430          2627.111589
# 309  Large & Mid Cap Fund  2019-04-01       4352083          1179.382306
# 310          Mid Cap Fund  2019-04-01       6128989          2060.461317
# 311        Small Cap Fund  2019-04-01       4946766          1772.598757
#
#      Redemptions_Cr  Net_Inflows_Cr     Net_AUM_Cr  Average_Net_AUM_Cr
# ...

# %%
df1.shape
# Out:
# (312, 8)

# %%
df1.columns
# Out:
# Index(['Scheme_Category', 'Date', 'No_of_Folios', 'SIP_Contribution_Cr',
#        'Redemptions_Cr', 'Net_Inflows_Cr', 'Net_AUM_Cr', 'Average_Net_AUM_Cr'],
#       dtype='object')

# %%
df1.Scheme_Category.unique()
# Out:
# array(['Large Cap Fund', 'Large & Mid Cap Fund', 'Mid Cap Fund',
#        'Small Cap Fund'], dtype=object)

# %%
df1.Scheme_Category.nunique()
# Out:
# 4

# %%
df1.Scheme_Category.value_counts()
# Out:
# Scheme_Category
# Large Cap Fund          78
# Large & Mid Cap Fund    78
# Mid Cap Fund            78
# Small Cap Fund          78
# Name: count, dtype: int64
